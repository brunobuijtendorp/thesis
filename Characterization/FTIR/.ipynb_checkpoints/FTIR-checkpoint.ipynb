# %%
import numpy as np
import matplotlib.pyplot as plt
import os
data_dir = os.getcwd() + '/data/'

# %%
data_100C = np.loadtxt(data_dir + 'a-Si PECVD 20190514/100C_20190514.CSV', delimiter=';')
data_250C = np.loadtxt(data_dir + 'a-Si PECVD 20190514/250C_20190514.CSV', delimiter=';')
data_350C = np.loadtxt(data_dir + 'a-Si PECVD 20190514/350C_20190514.CSV', delimiter=';')
data_background = np.loadtxt(data_dir + 'a-Si PECVD 20190514/background_20190514.CSV', delimiter=';')
data_background_unox = np.loadtxt(data_dir + 'a-Si_PECVD_20190430/background_blank_wafer_crystalline_Si_20190430.CSV', delimiter=';')

# %%
# May 14 2019

fig, ax = plt.subplots()
ax.plot(data_100C[:,0], data_100C[:,1])
ax.set_title("FTIR measurement of 100 °C wafer")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Transmission (%)')
ax.axvline(2003, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2080, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2120, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_250C[:,0], data_250C[:,1])
ax.set_title("FTIR measurement of 250 °C")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Transmission (%)')
ax.axvline(2003, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2080, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2120, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_350C[:,0], data_350C[:,1])
ax.set_title("FTIR measurement of 350 °C wafer")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Transmission (%)')
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_background[:,0], data_background[:,1])
ax.set_title("FTIR measurement of thermally oxidized substrate")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Transmission (%)')
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_background_unox[:,0], data_background_unox[:,1])
ax.set_title("FTIR measurement of blank substrate")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Transmission (%)')
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

# %%
# Background removal
fig, ax = plt.subplots()
ax.plot(data_100C[:,0], data_100C[:,1]/data_background[:,1])
ax.set_title("FTIR measurement of 100 °C wafer")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Transmission (%)')
ax.axvline(2003, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2080, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2120, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_250C[:,0], data_250C[:,1]/data_background[:,1])
ax.set_title("FTIR measurement of 250 °C")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Transmission (%)')
ax.axvline(2003, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2080, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2120, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_350C[:,0], data_350C[:,1]/data_background[:,1])
ax.set_title("FTIR measurement of 350 °C wafer")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Transmission (%)')
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

# %%
# In absorbance
fig, ax = plt.subplots()
ax.plot(data_100C[:,0], 2-np.log10(data_100C[:,1]))
ax.set_title("FTIR measurement of 100 °C wafer")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Absorbance)')
ax.axvline(2003, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2080, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2120, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_250C[:,0], 2-np.log10(data_250C[:,1]))
ax.set_title("FTIR measurement of 250 °C")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Absorbance')
ax.axvline(2003, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2080, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2120, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_350C[:,0], 2-np.log10(data_350C[:,1]))
ax.set_title("FTIR measurement of 350 °C wafer")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Absorbance')
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_background[:,0], 2-np.log10(data_background[:,1]))
ax.set_title("FTIR measurement of thermally oxidized substrate")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Absorbance')
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_background_unox[:,0], 2-np.log10(data_background_unox[:,1]))
ax.set_title("FTIR measurement of blank substrate")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Absorbance')
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

# %%
# Background removal, in absorbance
fig, ax = plt.subplots()
ax.plot(data_100C[:,0], 2-np.log10(data_100C[:,1]/data_background[:,1]))
ax.set_title("FTIR measurement of 100 °C wafer")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Absorbance)')
ax.axvline(2003, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2080, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2120, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_250C[:,0], 2-np.log10(data_250C[:,1]/data_background[:,1]))
ax.set_title("FTIR measurement of 250 °C")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Absorbance')
ax.axvline(2003, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2080, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(2120, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)

fig, ax = plt.subplots()
ax.plot(data_350C[:,0], 2-np.log10(data_350C[:,1]/data_background[:,1]))
ax.set_title("FTIR measurement of 350 °C wafer")
ax.set_xlabel(r'Wavenumber ($cm^{-1}$)')
ax.set_ylabel('Absorbance')
ax.axvline(630, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1085, linestyle='--', color = 'k', alpha = 0.2)
ax.axvline(1107, linestyle='--', color = 'k', alpha = 0.2)
