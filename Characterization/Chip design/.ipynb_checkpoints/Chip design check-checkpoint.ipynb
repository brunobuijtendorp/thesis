# %%
import numpy as np
eps_eff = 5.5

coup_L = np.array([[730, np.NAN, 215.25, np.NAN , np.NAN],
                   [579.5, np.NAN, np.NAN, np.NAN , np.NAN],
                   [575.5, np.NAN, np.NAN, np.NAN , np.NAN]])
coup_v = np.array([[94, np.NAN, 94, np.NAN , np.NAN],
                   [82, np.NAN, np.NAN, np.NAN, np.NAN],
                   [70, np.NAN, np.NAN, np.NAN, np.NAN]])
R = np.array([[51.5, np.NAN, 51.5, np.NAN, np.NAN],
              [80.75, np.NAN, np.NAN, np.NAN, np.NAN],
              [124.25, np.NAN, np.NAN, np.NAN, np.NAN]])
coup_h = np.array([[131, np.NAN, 153.15, np.NAN, np.NAN],
                   [124.25, np.NAN, np.NAN, np.NAN, np.NAN],
                   [99, np.NAN, np.NAN, np.NAN, np.NAN]])
KID_h = np.array([[365, np.NAN, 409.55, np.NAN, np.NAN],
                  [410, np.NAN, np.NAN, np.NAN, np.NAN],
                  [445.75, np.NAN, np.NAN, np.NAN, np.NAN]])
KID_lasth = np.array([[182.5, np.NAN, 204.75, np.NAN, np.NAN],
                      [205, np.NAN, np.NAN, np.NAN, np.NAN],
                      [223, np.NAN, np.NAN, np.NAN, np.NAN]])
antenna_v = 2

# %%
KID_total_L = 1e-6 * (coup_L + coup_v + np.pi/2*R + coup_h + 8*np.pi*R + 7*KID_h + antenna_v + KID_lasth)
KID_F = 1e-9 * 2.9979*10**8 / KID_total_L / 4 / np.sqrt(eps_eff)

# %%
KID_lasth / KID_h
# Out:
# array([[0.5       ,        nan, 0.49993896,        nan,        nan],
#        [0.5       ,        nan,        nan,        nan,        nan],
#        [0.50028043,        nan,        nan,        nan,        nan]])

# %%
coup_L + coup_v + np.pi/2*R + coup_h + 8*np.pi*R + 7*KID_h + antenna_v + KID_lasth
# Out:
# array([[5069.73218411,           nan,           nan,           nan,
#                   nan],
#        [6019.06065761,           nan,           nan,           nan,
#                   nan],
#        [7407.66454127,           nan,           nan,           nan,
#                   nan]])
